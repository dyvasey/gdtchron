# %% [markdown]
# # Run Example ASPECT Exhumation Model
# This notebook does not use GDTchron but instead contains the shell scripts necessary to run an example ASPECT model (`exhumation_box.prm`) simulating exhumation of a 2D box. Once run, the model results can be processed with GDTchron using the `process_model.ipynb` notebook, and a publication-ready figure of the results can be made with `figures_model.ipynb`.
#
# Running this notebook requires that ASPECT is installed and that optimized mode can be accessed with `aspect-release`. If you are using ASPECT in the accompanying Docker container, this is already enabled.

# %%
# Show number of available processors on local system and divide by 2
import os

os.environ['NP'] = str(int(os.cpu_count() / 2))

# !echo $NP
# Out:
# 36

# %%
# Run ASPECT on exhumation_box model with half the system processors
# !mpirun -np $NP aspect-release exhumation_box.prm
# Out:
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# -----------------------------------------------------------------------------
# --                             This is ASPECT                              --
# -- The Advanced Solver for Planetary Evolution, Convection, and Tectonics. --
# -----------------------------------------------------------------------------
# --     . version 3.1.0-pre (main, f56842eca)
# --     . using deal.II 9.5.1
# --     .       with 32 bit indices
# --     .       with vectorization level 0 (disabled, 1 doubles, 64 bits)
# --     . using Trilinos 13.2.0
# --     . using p4est 2.3.6
# --     . using Geodynamic World Builder 1.0.0
# --     . running in OPTIMIZED mode
# --     . running with 36 MPI processes
# -----------------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------------
# The output directory <output_exhumation_box/> provided in the input file appears not to exist.
# ASPECT will create it for you.
# -----------------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&cbfheatflux=1&mf=1&particles=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------
# Number of active cells: 2,000 (on 3 levels)
# Number of degrees of freedom: 35,085 (16,482+2,121+8,241+8,241)
#
# *** Timestep 0:  t=0 years, dt=0 years
#    Solving temperature system... 0 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 28+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Writing graphical output:            output_exhumation_box/solution/solution-00000
#      Writing particle output:             output_exhumation_box/particles/particles-00000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |     0.751s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         1 |    0.0217s |       2.9% |
# | Assemble temperature system      |         1 |    0.0139s |       1.8% |
# | Build Stokes preconditioner      |         1 |  0.000633s |         0% |
# | Build temperature preconditioner |         1 |  0.000611s |         0% |
# | Initialization                   |         1 |     0.111s |        15% |
# | Particles: Advect                |         2 |  0.000714s |         0% |
# | Particles: Copy                  |         1 |  9.17e-05s |         0% |
# | Particles: Exchange ghosts       |         2 |     0.002s |      0.27% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |      0.29% |
# | Particles: Interpolate           |         1 |   0.00395s |      0.53% |
# | Particles: Sort                  |         2 |   0.00115s |      0.15% |
# | Particles: Update properties     |         1 |  0.000369s |         0% |
# | Postprocessing                   |         1 |    0.0966s |        13% |
# | Setup dof systems                |         1 |    0.0531s |       7.1% |
# | Setup initial conditions         |         1 |    0.0435s |       5.8% |
# | Setup matrices                   |         1 |    0.0796s |        11% |
# | Solve Stokes system              |         1 |     0.284s |        38% |
# | Solve temperature system         |         1 |    0.0148s |         2% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 1:  t=20000 years, dt=20000 years
#    Solving temperature system... 15 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 0+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |     0.919s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         2 |    0.0468s |       5.1% |
# | Assemble temperature system      |         2 |    0.0263s |       2.9% |
# | Build Stokes preconditioner      |         2 |   0.00148s |      0.16% |
# | Build temperature preconditioner |         2 |   0.00127s |      0.14% |
# | Initialization                   |         1 |     0.111s |        12% |
# | Particles: Advect                |         4 |   0.00178s |      0.19% |
# | Particles: Copy                  |         2 |  0.000434s |         0% |
# | Particles: Exchange ghosts       |         3 |   0.00282s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |      0.24% |
# | Particles: Interpolate           |         2 |    0.0069s |      0.75% |
# | Particles: Sort                  |         4 |   0.00185s |       0.2% |
# | Particles: Update properties     |         2 |  0.000936s |       0.1% |
# | Postprocessing                   |         2 |     0.121s |        13% |
# | Setup dof systems                |         1 |    0.0531s |       5.8% |
# | Setup initial conditions         |         1 |    0.0435s |       4.7% |
# | Setup matrices                   |         1 |    0.0796s |       8.7% |
# | Solve Stokes system              |         2 |     0.351s |        38% |
# | Solve temperature system         |         2 |    0.0404s |       4.4% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 2:  t=40000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 0+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      1.08s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         3 |    0.0688s |       6.4% |
# | Assemble temperature system      |         3 |    0.0359s |       3.3% |
# | Build Stokes preconditioner      |         3 |    0.0021s |      0.19% |
# | Build temperature preconditioner |         3 |   0.00175s |      0.16% |
# | Initialization                   |         1 |     0.111s |        10% |
# | Particles: Advect                |         6 |   0.00245s |      0.23% |
# | Particles: Copy                  |         3 |  0.000673s |         0% |
# | Particles: Exchange ghosts       |         4 |   0.00343s |      0.32% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |       0.2% |
# | Particles: Interpolate           |         3 |   0.00951s |      0.88% |
# | Particles: Sort                  |         6 |   0.00249s |      0.23% |
# | Particles: Update properties     |         3 |   0.00131s |      0.12% |
# | Postprocessing                   |         3 |     0.145s |        13% |
# | Setup dof systems                |         1 |    0.0531s |       4.9% |
# | Setup initial conditions         |         1 |    0.0435s |         4% |
# | Setup matrices                   |         1 |    0.0796s |       7.4% |
# | Solve Stokes system              |         3 |     0.415s |        38% |
# | Solve temperature system         |         3 |    0.0607s |       5.6% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 3:  t=60000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 0+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      1.24s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         4 |    0.0909s |       7.3% |
# | Assemble temperature system      |         4 |    0.0456s |       3.7% |
# | Build Stokes preconditioner      |         4 |   0.00272s |      0.22% |
# | Build temperature preconditioner |         4 |   0.00222s |      0.18% |
# | Initialization                   |         1 |     0.111s |       8.9% |
# | Particles: Advect                |         8 |   0.00311s |      0.25% |
# | Particles: Copy                  |         4 |  0.000911s |         0% |
# | Particles: Exchange ghosts       |         5 |   0.00406s |      0.33% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |      0.17% |
# | Particles: Interpolate           |         4 |    0.0122s |      0.98% |
# | Particles: Sort                  |         8 |   0.00312s |      0.25% |
# | Particles: Update properties     |         4 |   0.00168s |      0.14% |
# | Postprocessing                   |         4 |     0.169s |        14% |
# | Setup dof systems                |         1 |    0.0531s |       4.3% |
# | Setup initial conditions         |         1 |    0.0435s |       3.5% |
# | Setup matrices                   |         1 |    0.0796s |       6.4% |
# | Solve Stokes system              |         4 |     0.479s |        39% |
# | Solve temperature system         |         4 |    0.0809s |       6.5% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 4:  t=80000 years, dt=20000 years
#    Solving temperature system... 10 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 1+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      1.42s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         5 |     0.113s |         8% |
# | Assemble temperature system      |         5 |    0.0551s |       3.9% |
# | Build Stokes preconditioner      |         5 |   0.00334s |      0.24% |
# | Build temperature preconditioner |         5 |    0.0027s |      0.19% |
# | Initialization                   |         1 |     0.111s |       7.8% |
# | Particles: Advect                |        10 |   0.00396s |      0.28% |
# | Particles: Copy                  |         5 |   0.00116s |         0% |
# | Particles: Exchange ghosts       |         6 |    0.0047s |      0.33% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |      0.15% |
# | Particles: Interpolate           |         5 |    0.0148s |         1% |
# | Particles: Sort                  |        10 |   0.00373s |      0.26% |
# | Particles: Update properties     |         5 |   0.00203s |      0.14% |
# | Postprocessing                   |         5 |     0.193s |        14% |
# | Setup dof systems                |         1 |    0.0531s |       3.7% |
# | Setup initial conditions         |         1 |    0.0435s |       3.1% |
# | Setup matrices                   |         1 |    0.0796s |       5.6% |
# | Solve Stokes system              |         5 |     0.558s |        39% |
# | Solve temperature system         |         5 |       0.1s |       7.1% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 5:  t=100000 years, dt=20000 years
#    Solving temperature system... 10 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 3+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Writing graphical output:            output_exhumation_box/solution/solution-00001
#      Writing particle output:             output_exhumation_box/particles/particles-00001
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      1.67s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         6 |     0.134s |         8% |
# | Assemble temperature system      |         6 |    0.0648s |       3.9% |
# | Build Stokes preconditioner      |         6 |   0.00397s |      0.24% |
# | Build temperature preconditioner |         6 |   0.00319s |      0.19% |
# | Initialization                   |         1 |     0.111s |       6.6% |
# | Particles: Advect                |        12 |   0.00463s |      0.28% |
# | Particles: Copy                  |         6 |    0.0014s |         0% |
# | Particles: Exchange ghosts       |         7 |   0.00527s |      0.32% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |      0.13% |
# | Particles: Interpolate           |         6 |    0.0175s |         1% |
# | Particles: Sort                  |        12 |   0.00431s |      0.26% |
# | Particles: Update properties     |         6 |   0.00239s |      0.14% |
# | Postprocessing                   |         6 |     0.286s |        17% |
# | Setup dof systems                |         1 |    0.0531s |       3.2% |
# | Setup initial conditions         |         1 |    0.0435s |       2.6% |
# | Setup matrices                   |         1 |    0.0796s |       4.8% |
# | Solve Stokes system              |         6 |     0.649s |        39% |
# | Solve temperature system         |         6 |      0.12s |       7.2% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 6:  t=120000 years, dt=20000 years
#    Solving temperature system... 10 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 4+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      1.87s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         7 |     0.156s |       8.4% |
# | Assemble temperature system      |         7 |    0.0749s |         4% |
# | Build Stokes preconditioner      |         7 |   0.00459s |      0.25% |
# | Build temperature preconditioner |         7 |   0.00367s |       0.2% |
# | Initialization                   |         1 |     0.111s |       5.9% |
# | Particles: Advect                |        14 |   0.00533s |      0.29% |
# | Particles: Copy                  |         7 |   0.00168s |         0% |
# | Particles: Exchange ghosts       |         8 |   0.00588s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |      0.12% |
# | Particles: Interpolate           |         7 |      0.02s |       1.1% |
# | Particles: Sort                  |        14 |   0.00494s |      0.26% |
# | Particles: Update properties     |         7 |   0.00276s |      0.15% |
# | Postprocessing                   |         7 |      0.31s |        17% |
# | Setup dof systems                |         1 |    0.0531s |       2.8% |
# | Setup initial conditions         |         1 |    0.0435s |       2.3% |
# | Setup matrices                   |         1 |    0.0796s |       4.3% |
# | Solve Stokes system              |         7 |     0.751s |        40% |
# | Solve temperature system         |         7 |      0.14s |       7.5% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 7:  t=140000 years, dt=20000 years
#    Solving temperature system... 10 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 4+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      2.07s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         8 |     0.178s |       8.6% |
# | Assemble temperature system      |         8 |    0.0847s |       4.1% |
# | Build Stokes preconditioner      |         8 |   0.00521s |      0.25% |
# | Build temperature preconditioner |         8 |   0.00416s |       0.2% |
# | Initialization                   |         1 |     0.111s |       5.4% |
# | Particles: Advect                |        16 |     0.006s |      0.29% |
# | Particles: Copy                  |         8 |   0.00192s |         0% |
# | Particles: Exchange ghosts       |         9 |   0.00647s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |       0.1% |
# | Particles: Interpolate           |         8 |    0.0226s |       1.1% |
# | Particles: Sort                  |        16 |   0.00557s |      0.27% |
# | Particles: Update properties     |         8 |   0.00313s |      0.15% |
# | Postprocessing                   |         8 |     0.334s |        16% |
# | Setup dof systems                |         1 |    0.0531s |       2.6% |
# | Setup initial conditions         |         1 |    0.0435s |       2.1% |
# | Setup matrices                   |         1 |    0.0796s |       3.8% |
# | Solve Stokes system              |         8 |     0.853s |        41% |
# | Solve temperature system         |         8 |     0.159s |       7.7% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 8:  t=160000 years, dt=20000 years
#    Solving temperature system... 10 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 1+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      2.25s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |         9 |       0.2s |       8.9% |
# | Assemble temperature system      |         9 |    0.0943s |       4.2% |
# | Build Stokes preconditioner      |         9 |   0.00583s |      0.26% |
# | Build temperature preconditioner |         9 |   0.00463s |      0.21% |
# | Initialization                   |         1 |     0.111s |       4.9% |
# | Particles: Advect                |        18 |    0.0067s |       0.3% |
# | Particles: Copy                  |         9 |   0.00218s |         0% |
# | Particles: Exchange ghosts       |        10 |   0.00706s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |         9 |    0.0253s |       1.1% |
# | Particles: Sort                  |        18 |   0.00617s |      0.27% |
# | Particles: Update properties     |         9 |   0.00349s |      0.16% |
# | Postprocessing                   |         9 |     0.358s |        16% |
# | Setup dof systems                |         1 |    0.0531s |       2.4% |
# | Setup initial conditions         |         1 |    0.0435s |       1.9% |
# | Setup matrices                   |         1 |    0.0796s |       3.5% |
# | Solve Stokes system              |         9 |     0.932s |        42% |
# | Solve temperature system         |         9 |     0.179s |         8% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 9:  t=180000 years, dt=20000 years
#    Solving temperature system... 10 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 3+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      2.44s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        10 |     0.223s |       9.1% |
# | Assemble temperature system      |        10 |     0.104s |       4.3% |
# | Build Stokes preconditioner      |        10 |   0.00645s |      0.26% |
# | Build temperature preconditioner |        10 |   0.00512s |      0.21% |
# | Initialization                   |         1 |     0.111s |       4.5% |
# | Particles: Advect                |        20 |   0.00737s |       0.3% |
# | Particles: Copy                  |        10 |   0.00236s |         0% |
# | Particles: Exchange ghosts       |        11 |   0.00766s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        10 |    0.0279s |       1.1% |
# | Particles: Sort                  |        20 |    0.0068s |      0.28% |
# | Particles: Update properties     |        10 |   0.00385s |      0.16% |
# | Postprocessing                   |        10 |     0.382s |        16% |
# | Setup dof systems                |         1 |    0.0531s |       2.2% |
# | Setup initial conditions         |         1 |    0.0435s |       1.8% |
# | Setup matrices                   |         1 |    0.0796s |       3.3% |
# | Solve Stokes system              |        10 |      1.03s |        42% |
# | Solve temperature system         |        10 |     0.198s |       8.1% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 10:  t=200000 years, dt=20000 years
#    Solving temperature system... 10 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 3+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Writing graphical output:            output_exhumation_box/solution/solution-00002
#      Writing particle output:             output_exhumation_box/particles/particles-00002
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |       2.7s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        11 |     0.244s |       9.1% |
# | Assemble temperature system      |        11 |     0.114s |       4.2% |
# | Build Stokes preconditioner      |        11 |   0.00708s |      0.26% |
# | Build temperature preconditioner |        11 |    0.0056s |      0.21% |
# | Initialization                   |         1 |     0.111s |       4.1% |
# | Particles: Advect                |        22 |   0.00804s |       0.3% |
# | Particles: Copy                  |        11 |   0.00261s |         0% |
# | Particles: Exchange ghosts       |        12 |   0.00826s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        11 |    0.0306s |       1.1% |
# | Particles: Sort                  |        22 |   0.00742s |      0.28% |
# | Particles: Update properties     |        11 |   0.00422s |      0.16% |
# | Postprocessing                   |        11 |     0.475s |        18% |
# | Setup dof systems                |         1 |    0.0531s |         2% |
# | Setup initial conditions         |         1 |    0.0435s |       1.6% |
# | Setup matrices                   |         1 |    0.0796s |         3% |
# | Solve Stokes system              |        11 |      1.12s |        42% |
# | Solve temperature system         |        11 |     0.218s |       8.1% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 11:  t=220000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 2+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      2.89s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        12 |     0.268s |       9.3% |
# | Assemble temperature system      |        12 |     0.126s |       4.4% |
# | Build Stokes preconditioner      |        12 |   0.00793s |      0.27% |
# | Build temperature preconditioner |        12 |   0.00625s |      0.22% |
# | Initialization                   |         1 |     0.111s |       3.8% |
# | Particles: Advect                |        24 |    0.0091s |      0.32% |
# | Particles: Copy                  |        12 |    0.0029s |       0.1% |
# | Particles: Exchange ghosts       |        13 |   0.00905s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        12 |    0.0334s |       1.2% |
# | Particles: Sort                  |        24 |   0.00813s |      0.28% |
# | Particles: Update properties     |        12 |   0.00478s |      0.17% |
# | Postprocessing                   |        12 |       0.5s |        17% |
# | Setup dof systems                |         1 |    0.0531s |       1.8% |
# | Setup initial conditions         |         1 |    0.0435s |       1.5% |
# | Setup matrices                   |         1 |    0.0796s |       2.8% |
# | Solve Stokes system              |        12 |      1.21s |        42% |
# | Solve temperature system         |        12 |     0.237s |       8.2% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 12:  t=240000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 1+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      3.06s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        13 |      0.29s |       9.5% |
# | Assemble temperature system      |        13 |     0.136s |       4.4% |
# | Build Stokes preconditioner      |        13 |   0.00854s |      0.28% |
# | Build temperature preconditioner |        13 |   0.00673s |      0.22% |
# | Initialization                   |         1 |     0.111s |       3.6% |
# | Particles: Advect                |        26 |   0.00977s |      0.32% |
# | Particles: Copy                  |        13 |   0.00316s |       0.1% |
# | Particles: Exchange ghosts       |        14 |   0.00964s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        13 |    0.0361s |       1.2% |
# | Particles: Sort                  |        26 |   0.00875s |      0.29% |
# | Particles: Update properties     |        13 |   0.00516s |      0.17% |
# | Postprocessing                   |        13 |     0.524s |        17% |
# | Setup dof systems                |         1 |    0.0531s |       1.7% |
# | Setup initial conditions         |         1 |    0.0435s |       1.4% |
# | Setup matrices                   |         1 |    0.0796s |       2.6% |
# | Solve Stokes system              |        13 |      1.29s |        42% |
# | Solve temperature system         |        13 |     0.256s |       8.4% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 13:  t=260000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 3+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      3.25s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        14 |     0.312s |       9.6% |
# | Assemble temperature system      |        14 |     0.145s |       4.5% |
# | Build Stokes preconditioner      |        14 |   0.00917s |      0.28% |
# | Build temperature preconditioner |        14 |   0.00721s |      0.22% |
# | Initialization                   |         1 |     0.111s |       3.4% |
# | Particles: Advect                |        28 |    0.0105s |      0.32% |
# | Particles: Copy                  |        14 |    0.0034s |       0.1% |
# | Particles: Exchange ghosts       |        15 |    0.0102s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        14 |    0.0388s |       1.2% |
# | Particles: Sort                  |        28 |   0.00939s |      0.29% |
# | Particles: Update properties     |        14 |   0.00553s |      0.17% |
# | Postprocessing                   |        14 |     0.548s |        17% |
# | Setup dof systems                |         1 |    0.0531s |       1.6% |
# | Setup initial conditions         |         1 |    0.0435s |       1.3% |
# | Setup matrices                   |         1 |    0.0796s |       2.4% |
# | Solve Stokes system              |        14 |      1.38s |        43% |
# | Solve temperature system         |        14 |     0.275s |       8.5% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 14:  t=280000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 1+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      3.43s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        15 |     0.334s |       9.7% |
# | Assemble temperature system      |        15 |     0.155s |       4.5% |
# | Build Stokes preconditioner      |        15 |   0.00979s |      0.29% |
# | Build temperature preconditioner |        15 |    0.0077s |      0.22% |
# | Initialization                   |         1 |     0.111s |       3.2% |
# | Particles: Advect                |        30 |    0.0111s |      0.32% |
# | Particles: Copy                  |        15 |   0.00365s |      0.11% |
# | Particles: Exchange ghosts       |        16 |    0.0108s |      0.32% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        15 |    0.0414s |       1.2% |
# | Particles: Sort                  |        30 |      0.01s |      0.29% |
# | Particles: Update properties     |        15 |   0.00591s |      0.17% |
# | Postprocessing                   |        15 |     0.572s |        17% |
# | Setup dof systems                |         1 |    0.0531s |       1.5% |
# | Setup initial conditions         |         1 |    0.0435s |       1.3% |
# | Setup matrices                   |         1 |    0.0796s |       2.3% |
# | Solve Stokes system              |        15 |      1.46s |        43% |
# | Solve temperature system         |        15 |     0.294s |       8.6% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 15:  t=300000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 1+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Writing graphical output:            output_exhumation_box/solution/solution-00003
#      Writing particle output:             output_exhumation_box/particles/particles-00003
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      3.68s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        16 |     0.356s |       9.7% |
# | Assemble temperature system      |        16 |     0.165s |       4.5% |
# | Build Stokes preconditioner      |        16 |    0.0104s |      0.28% |
# | Build temperature preconditioner |        16 |   0.00818s |      0.22% |
# | Initialization                   |         1 |     0.111s |         3% |
# | Particles: Advect                |        32 |    0.0118s |      0.32% |
# | Particles: Copy                  |        16 |   0.00389s |      0.11% |
# | Particles: Exchange ghosts       |        17 |    0.0114s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        16 |     0.044s |       1.2% |
# | Particles: Sort                  |        32 |    0.0106s |      0.29% |
# | Particles: Update properties     |        16 |   0.00629s |      0.17% |
# | Postprocessing                   |        16 |     0.666s |        18% |
# | Setup dof systems                |         1 |    0.0531s |       1.4% |
# | Setup initial conditions         |         1 |    0.0435s |       1.2% |
# | Setup matrices                   |         1 |    0.0796s |       2.2% |
# | Solve Stokes system              |        16 |      1.54s |        42% |
# | Solve temperature system         |        16 |     0.313s |       8.5% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 16:  t=320000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 3+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      3.88s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        17 |      0.38s |       9.8% |
# | Assemble temperature system      |        17 |     0.177s |       4.6% |
# | Build Stokes preconditioner      |        17 |    0.0113s |      0.29% |
# | Build temperature preconditioner |        17 |   0.00884s |      0.23% |
# | Initialization                   |         1 |     0.111s |       2.9% |
# | Particles: Advect                |        34 |    0.0129s |      0.33% |
# | Particles: Copy                  |        17 |   0.00426s |      0.11% |
# | Particles: Exchange ghosts       |        18 |    0.0122s |      0.31% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        17 |    0.0485s |       1.2% |
# | Particles: Sort                  |        34 |    0.0113s |      0.29% |
# | Particles: Update properties     |        17 |   0.00686s |      0.18% |
# | Postprocessing                   |        17 |     0.691s |        18% |
# | Setup dof systems                |         1 |    0.0531s |       1.4% |
# | Setup initial conditions         |         1 |    0.0435s |       1.1% |
# | Setup matrices                   |         1 |    0.0796s |       2.1% |
# | Solve Stokes system              |        17 |      1.64s |        42% |
# | Solve temperature system         |        17 |     0.333s |       8.6% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 17:  t=340000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 0+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      4.04s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        18 |     0.402s |       9.9% |
# | Assemble temperature system      |        18 |     0.186s |       4.6% |
# | Build Stokes preconditioner      |        18 |    0.0119s |      0.29% |
# | Build temperature preconditioner |        18 |   0.00931s |      0.23% |
# | Initialization                   |         1 |     0.111s |       2.7% |
# | Particles: Advect                |        36 |    0.0136s |      0.34% |
# | Particles: Copy                  |        18 |   0.00446s |      0.11% |
# | Particles: Exchange ghosts       |        19 |    0.0128s |      0.32% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |        18 |    0.0511s |       1.3% |
# | Particles: Sort                  |        36 |     0.012s |       0.3% |
# | Particles: Update properties     |        18 |   0.00724s |      0.18% |
# | Postprocessing                   |        18 |     0.715s |        18% |
# | Setup dof systems                |         1 |    0.0531s |       1.3% |
# | Setup initial conditions         |         1 |    0.0435s |       1.1% |
# | Setup matrices                   |         1 |    0.0796s |         2% |
# | Solve Stokes system              |        18 |      1.71s |        42% |
# | Solve temperature system         |        18 |     0.352s |       8.7% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 18:  t=360000 years, dt=20000 years
#    Solving temperature system... 9 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 4+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 586.3 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |      4.24s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# ...
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |       996 |      2.76s |       1.3% |
# | Particles: Sort                  |      1992 |     0.688s |      0.33% |
# | Particles: Update properties     |       996 |     0.418s |       0.2% |
# | Postprocessing                   |       996 |      39.9s |        19% |
# | Setup dof systems                |         1 |    0.0531s |         0% |
# | Setup initial conditions         |         1 |    0.0435s |         0% |
# | Setup matrices                   |         1 |    0.0796s |         0% |
# | Solve Stokes system              |       996 |      91.2s |        44% |
# | Solve temperature system         |       996 |      20.7s |       9.9% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 208s
# *** Timestep 996:  t=1.992e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 1+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 588.7 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        96053
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |       208s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |       997 |        23s |        11% |
# | Assemble temperature system      |       997 |      10.4s |         5% |
# | Build Stokes preconditioner      |       997 |     0.656s |      0.31% |
# | Build temperature preconditioner |       997 |     0.523s |      0.25% |
# | Initialization                   |         1 |     0.111s |         0% |
# | Particles: Advect                |      1994 |     0.817s |      0.39% |
# | Particles: Copy                  |       997 |     0.297s |      0.14% |
# | Particles: Exchange ghosts       |       998 |     0.634s |       0.3% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |       997 |      2.76s |       1.3% |
# | Particles: Sort                  |      1994 |     0.688s |      0.33% |
# | Particles: Update properties     |       997 |     0.418s |       0.2% |
# | Postprocessing                   |       997 |      39.9s |        19% |
# | Setup dof systems                |         1 |    0.0531s |         0% |
# | Setup initial conditions         |         1 |    0.0435s |         0% |
# | Setup matrices                   |         1 |    0.0796s |         0% |
# | Solve Stokes system              |       997 |      91.3s |        44% |
# | Solve temperature system         |       997 |      20.7s |       9.9% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 208s
# *** Timestep 997:  t=1.994e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 2+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 588.6 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        96053
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |       208s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |       998 |        23s |        11% |
# | Assemble temperature system      |       998 |      10.4s |         5% |
# | Build Stokes preconditioner      |       998 |     0.657s |      0.31% |
# | Build temperature preconditioner |       998 |     0.524s |      0.25% |
# | Initialization                   |         1 |     0.111s |         0% |
# | Particles: Advect                |      1996 |     0.817s |      0.39% |
# | Particles: Copy                  |       998 |     0.297s |      0.14% |
# | Particles: Exchange ghosts       |       999 |     0.635s |       0.3% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |       998 |      2.76s |       1.3% |
# | Particles: Sort                  |      1996 |     0.689s |      0.33% |
# | Particles: Update properties     |       998 |     0.419s |       0.2% |
# | Postprocessing                   |       998 |        40s |        19% |
# | Setup dof systems                |         1 |    0.0531s |         0% |
# | Setup initial conditions         |         1 |    0.0435s |         0% |
# | Setup matrices                   |         1 |    0.0796s |         0% |
# | Solve Stokes system              |       998 |      91.4s |        44% |
# | Solve temperature system         |       998 |      20.7s |       9.9% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 208s
# *** Timestep 998:  t=1.996e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 3+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 588.6 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        96053
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |       209s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |       999 |        23s |        11% |
# | Assemble temperature system      |       999 |      10.5s |         5% |
# | Build Stokes preconditioner      |       999 |     0.657s |      0.31% |
# | Build temperature preconditioner |       999 |     0.524s |      0.25% |
# | Initialization                   |         1 |     0.111s |         0% |
# | Particles: Advect                |      1998 |     0.818s |      0.39% |
# | Particles: Copy                  |       999 |     0.298s |      0.14% |
# | Particles: Exchange ghosts       |      1000 |     0.636s |       0.3% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |       999 |      2.77s |       1.3% |
# | Particles: Sort                  |      1998 |      0.69s |      0.33% |
# | Particles: Update properties     |       999 |     0.419s |       0.2% |
# | Postprocessing                   |       999 |        40s |        19% |
# | Setup dof systems                |         1 |    0.0531s |         0% |
# | Setup initial conditions         |         1 |    0.0435s |         0% |
# | Setup matrices                   |         1 |    0.0796s |         0% |
# | Solve Stokes system              |       999 |      91.5s |        44% |
# | Solve temperature system         |       999 |      20.7s |       9.9% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 209s
# *** Timestep 999:  t=1.998e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 1+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 588.6 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Number of advected particles:        96053
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |       209s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |      1000 |        23s |        11% |
# | Assemble temperature system      |      1000 |      10.5s |         5% |
# | Build Stokes preconditioner      |      1000 |     0.658s |      0.32% |
# | Build temperature preconditioner |      1000 |     0.525s |      0.25% |
# | Initialization                   |         1 |     0.111s |         0% |
# | Particles: Advect                |      2000 |     0.819s |      0.39% |
# | Particles: Copy                  |      1000 |     0.298s |      0.14% |
# | Particles: Exchange ghosts       |      1001 |     0.636s |       0.3% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |      1000 |      2.77s |       1.3% |
# | Particles: Sort                  |      2000 |      0.69s |      0.33% |
# | Particles: Update properties     |      1000 |     0.419s |       0.2% |
# | Postprocessing                   |      1000 |        40s |        19% |
# | Setup dof systems                |         1 |    0.0531s |         0% |
# | Setup initial conditions         |         1 |    0.0435s |         0% |
# | Setup matrices                   |         1 |    0.0796s |         0% |
# | Solve Stokes system              |      1000 |      91.6s |        44% |
# | Solve temperature system         |      1000 |      20.8s |       9.9% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 209s
# *** Timestep 1000:  t=2e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Solving Stokes system (GMG)... 3+0 iterations.
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 588.6 K, 873 K
#      RMS, max velocity:                   4.61e-06 m/year, 1.09e-05 m/year
#      Writing graphical output:            output_exhumation_box/solution/solution-00200
#      Writing particle output:             output_exhumation_box/particles/particles-00200
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |       209s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |      1001 |      23.1s |        11% |
# | Assemble temperature system      |      1001 |      10.5s |         5% |
# | Build Stokes preconditioner      |      1001 |     0.659s |      0.31% |
# | Build temperature preconditioner |      1001 |     0.525s |      0.25% |
# | Initialization                   |         1 |     0.111s |         0% |
# | Particles: Advect                |      2002 |     0.819s |      0.39% |
# | Particles: Copy                  |      1001 |     0.298s |      0.14% |
# | Particles: Exchange ghosts       |      1002 |     0.637s |       0.3% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |      1001 |      2.77s |       1.3% |
# | Particles: Sort                  |      2002 |     0.691s |      0.33% |
# | Particles: Update properties     |      1001 |      0.42s |       0.2% |
# | Postprocessing                   |      1001 |      40.1s |        19% |
# | Setup dof systems                |         1 |    0.0531s |         0% |
# | Setup initial conditions         |         1 |    0.0435s |         0% |
# | Setup matrices                   |         1 |    0.0796s |         0% |
# | Solve Stokes system              |      1001 |      91.7s |        44% |
# | Solve temperature system         |      1001 |      20.8s |       9.9% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 209s
# Termination requested by criterion: end time
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |       209s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |      1001 |      23.1s |        11% |
# | Assemble temperature system      |      1001 |      10.5s |         5% |
# | Build Stokes preconditioner      |      1001 |     0.659s |      0.31% |
# | Build temperature preconditioner |      1001 |     0.525s |      0.25% |
# | Initialization                   |         1 |     0.111s |         0% |
# | Particles: Advect                |      2002 |     0.819s |      0.39% |
# | Particles: Copy                  |      1001 |     0.298s |      0.14% |
# | Particles: Exchange ghosts       |      1002 |     0.637s |       0.3% |
# | Particles: Generate              |         1 |  0.000568s |         0% |
# | Particles: Initialization        |         1 |  4.88e-05s |         0% |
# | Particles: Initialize properties |         1 |   0.00217s |         0% |
# | Particles: Interpolate           |      1001 |      2.77s |       1.3% |
# | Particles: Sort                  |      2002 |     0.691s |      0.33% |
# | Particles: Update properties     |      1001 |      0.42s |       0.2% |
# | Postprocessing                   |      1001 |      40.1s |        19% |
# | Setup dof systems                |         1 |    0.0531s |         0% |
# | Setup initial conditions         |         1 |    0.0435s |         0% |
# | Setup matrices                   |         1 |    0.0796s |         0% |
# | Solve Stokes system              |      1001 |      91.7s |        44% |
# | Solve temperature system         |      1001 |      20.8s |       9.9% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 209s
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&cbfheatflux=1&mf=1&particles=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------
