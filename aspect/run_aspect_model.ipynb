# %% [markdown]
# # Run Example ASPECT Uplift Model
# This notebook does not use GDTchron but instead contains the shell scripts necessary to run an example ASPECT model (`uplift_box.prm`) simulating uplift of a 2D box. Once run, the model results can be processed with GDTchron using the `process_model.ipynb` notebook, and a publication-ready figure of the results can be made with `figures_model.ipynb`.
#
# Running this notebook requires that ASPECT is installed and that optimized mode can be accessed with `aspect-release`. If you are using ASPECT in the accompanying Docker container, this is already enabled.
#
# The model consists of a two-dimensional box 100 km wide and 20 km deep. This box is assigned a linear geothermal gradient of 30°C with a surface temperature of 0°C. For 10 Myr, the box is kept static, so that the shallowest particles in or above the partial retention zones for AHe and ZHe and the partial annealing zone for AFT will accumulate He and fission tracks. At 10 Myr, the bottom of the box is pushed upwards at a rate of 1 mm/yr, allowing material to flow out the top of the box while the temperature structure of the box remains constant. This is designed to simulate 5 km of uplift with perfectly efficient erosion maintaining the original surface of the model. This uplift continues until 15 Myr, at which point the model remains static again until 20 Myr.

# %%
# Show number of available processors on local system and divide by 2
import os

os.environ['NP'] = str(int(os.cpu_count() / 2))

# !echo $NP
# Out:
# 36

# %%
# Run ASPECT on uplift_box model with half the system processors
# !mpirun -np $NP aspect-release uplift_box.prm
# Out:
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# -----------------------------------------------------------------------------
# --                             This is ASPECT                              --
# -- The Advanced Solver for Planetary Evolution, Convection, and Tectonics. --
# -----------------------------------------------------------------------------
# --     . version 3.1.0-pre (main, f56842eca)
# --     . using deal.II 9.5.1
# --     .       with 32 bit indices
# --     .       with vectorization level 0 (disabled, 1 doubles, 64 bits)
# --     . using Trilinos 13.2.0
# --     . using p4est 2.3.6
# --     . using Geodynamic World Builder 1.0.0
# --     . running in OPTIMIZED mode
# --     . running with 36 MPI processes
# -----------------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------------
# The output directory <output_uplift_box/> provided in the input file appears not to exist.
# ASPECT will create it for you.
# -----------------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&NewtonSolver=1&cbfheatflux=1&mf=1&particles=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------
# Number of active cells: 2,000 (on 3 levels)
# Number of degrees of freedom: 35,085 (16,482+2,121+8,241+8,241)
#
# *** Timestep 0:  t=0 years, dt=0 years
#    Solving temperature system... 0 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 1.70399e+12, v = 1.70399e+12, p = 0
#
#    Solving Stokes system (GMG)... 28+0 iterations.
#       Newton system information: Norm of the rhs: 1.70399e+12
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1
#
#    Solving Stokes system (GMG)... 27+0 iterations.
#       Newton system information: Norm of the rhs: 0.0472278, Derivative scaling factor: 0
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 2: 2.77161e-14
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box/solution/solution-00000
#      Writing particle output:             output_uplift_box/particles/particles-00000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      1.05s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         2 |     0.043s |       4.1% |
# | Assemble Stokes system rhs        |         2 |    0.0424s |       4.1% |
# | Assemble temperature system       |         1 |    0.0136s |       1.3% |
# | Build Stokes preconditioner       |         2 |   0.00124s |      0.12% |
# | Build temperature preconditioner  |         1 |  0.000608s |         0% |
# | Initialization                    |         1 |     0.111s |        11% |
# | Particles: Advect                 |         2 |  0.000721s |         0% |
# | Particles: Copy                   |         1 |   0.00013s |         0% |
# | Particles: Exchange ghosts        |         2 |   0.00229s |      0.22% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.26% |
# | Particles: Interpolate            |         1 |   0.00396s |      0.38% |
# | Particles: Sort                   |         2 |   0.00144s |      0.14% |
# | Particles: Update properties      |         1 |  0.000389s |         0% |
# | Postprocessing                    |         1 |    0.0523s |         5% |
# | Setup dof systems                 |         1 |    0.0526s |         5% |
# | Setup initial conditions          |         1 |      0.05s |       4.8% |
# | Setup matrices                    |         1 |    0.0799s |       7.6% |
# | Solve Stokes system               |         2 |     0.547s |        52% |
# | Solve temperature system          |         1 |    0.0146s |       1.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 1:  t=20000 years, dt=20000 years
#    Solving temperature system... 19 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 1.27196e+12, v = 1.27196e+12, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 23076.6
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.81426e-08
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      1.23s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         3 |    0.0647s |       5.3% |
# | Assemble Stokes system rhs        |         3 |     0.064s |       5.2% |
# | Assemble temperature system       |         2 |    0.0255s |       2.1% |
# | Build Stokes preconditioner       |         3 |   0.00185s |      0.15% |
# | Build temperature preconditioner  |         2 |   0.00127s |       0.1% |
# | Initialization                    |         1 |     0.111s |         9% |
# | Particles: Advect                 |         4 |   0.00142s |      0.12% |
# | Particles: Copy                   |         2 |  0.000436s |         0% |
# | Particles: Exchange ghosts        |         3 |   0.00287s |      0.23% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.22% |
# | Particles: Interpolate            |         2 |   0.00671s |      0.55% |
# | Particles: Sort                   |         4 |   0.00207s |      0.17% |
# | Particles: Update properties      |         2 |  0.000767s |         0% |
# | Postprocessing                    |         2 |     0.076s |       6.2% |
# | Setup dof systems                 |         1 |    0.0526s |       4.3% |
# | Setup initial conditions          |         1 |      0.05s |       4.1% |
# | Setup matrices                    |         1 |    0.0799s |       6.5% |
# | Solve Stokes system               |         3 |      0.61s |        50% |
# | Solve temperature system          |         2 |     0.043s |       3.5% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 2:  t=40000 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 45313.9
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 5.68967e-08
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      1.41s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         4 |    0.0863s |       6.1% |
# | Assemble Stokes system rhs        |         4 |    0.0855s |       6.1% |
# | Assemble temperature system       |         3 |    0.0349s |       2.5% |
# | Build Stokes preconditioner       |         4 |   0.00246s |      0.17% |
# | Build temperature preconditioner  |         3 |   0.00175s |      0.12% |
# | Initialization                    |         1 |     0.111s |       7.8% |
# | Particles: Advect                 |         6 |   0.00211s |      0.15% |
# | Particles: Copy                   |         3 |  0.000694s |         0% |
# | Particles: Exchange ghosts        |         4 |   0.00346s |      0.25% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.19% |
# | Particles: Interpolate            |         3 |   0.00941s |      0.67% |
# | Particles: Sort                   |         6 |   0.00269s |      0.19% |
# | Particles: Update properties      |         3 |   0.00115s |         0% |
# | Postprocessing                    |         3 |    0.0996s |       7.1% |
# | Setup dof systems                 |         1 |    0.0526s |       3.7% |
# | Setup initial conditions          |         1 |      0.05s |       3.5% |
# | Setup matrices                    |         1 |    0.0799s |       5.7% |
# | Solve Stokes system               |         4 |     0.673s |        48% |
# | Solve temperature system          |         3 |    0.0647s |       4.6% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# *** Timestep 3:  t=60000 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 66649.4
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 8.36859e-08
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      1.59s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         5 |     0.108s |       6.8% |
# | Assemble Stokes system rhs        |         5 |     0.107s |       6.7% |
# | Assemble temperature system       |         4 |    0.0443s |       2.8% |
# | Build Stokes preconditioner       |         5 |   0.00306s |      0.19% |
# | Build temperature preconditioner  |         4 |   0.00223s |      0.14% |
# | Initialization                    |         1 |     0.111s |       6.9% |
# | Particles: Advect                 |         8 |   0.00278s |      0.17% |
# | Particles: Copy                   |         4 |  0.000954s |         0% |
# | Particles: Exchange ghosts        |         5 |   0.00403s |      0.25% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.17% |
# | Particles: Interpolate            |         4 |    0.0121s |      0.76% |
# | Particles: Sort                   |         8 |   0.00328s |      0.21% |
# | Particles: Update properties      |         4 |   0.00151s |         0% |
# | Postprocessing                    |         4 |     0.123s |       7.7% |
# | Setup dof systems                 |         1 |    0.0526s |       3.3% |
# | Setup initial conditions          |         1 |      0.05s |       3.1% |
# | Setup matrices                    |         1 |    0.0799s |         5% |
# | Solve Stokes system               |         5 |     0.737s |        46% |
# | Solve temperature system          |         4 |    0.0862s |       5.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 4:  t=80000 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 87171
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.09453e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      1.78s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         6 |      0.13s |       7.3% |
# | Assemble Stokes system rhs        |         6 |     0.128s |       7.2% |
# | Assemble temperature system       |         5 |    0.0537s |         3% |
# | Build Stokes preconditioner       |         6 |   0.00367s |      0.21% |
# | Build temperature preconditioner  |         5 |   0.00272s |      0.15% |
# | Initialization                    |         1 |     0.111s |       6.2% |
# | Particles: Advect                 |        10 |   0.00345s |      0.19% |
# | Particles: Copy                   |         5 |   0.00121s |         0% |
# | Particles: Exchange ghosts        |         6 |   0.00462s |      0.26% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.15% |
# | Particles: Interpolate            |         5 |    0.0147s |      0.83% |
# | Particles: Sort                   |        10 |    0.0039s |      0.22% |
# | Particles: Update properties      |         5 |   0.00187s |      0.11% |
# | Postprocessing                    |         5 |     0.147s |       8.3% |
# | Setup dof systems                 |         1 |    0.0526s |         3% |
# | Setup initial conditions          |         1 |      0.05s |       2.8% |
# | Setup matrices                    |         1 |    0.0799s |       4.5% |
# | Solve Stokes system               |         6 |       0.8s |        45% |
# | Solve temperature system          |         5 |     0.108s |       6.1% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 5:  t=100000 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 106972
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.34315e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box/solution/solution-00001
#      Writing particle output:             output_uplift_box/particles/particles-00001
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      1.99s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         7 |     0.151s |       7.6% |
# | Assemble Stokes system rhs        |         7 |      0.15s |       7.5% |
# | Assemble temperature system       |         6 |    0.0631s |       3.2% |
# | Build Stokes preconditioner       |         7 |   0.00429s |      0.22% |
# | Build temperature preconditioner  |         6 |   0.00321s |      0.16% |
# | Initialization                    |         1 |     0.111s |       5.6% |
# | Particles: Advect                 |        12 |   0.00414s |      0.21% |
# | Particles: Copy                   |         6 |   0.00147s |         0% |
# | Particles: Exchange ghosts        |         7 |   0.00528s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.13% |
# | Particles: Interpolate            |         6 |    0.0174s |      0.87% |
# | Particles: Sort                   |        12 |    0.0045s |      0.23% |
# | Particles: Update properties      |         6 |   0.00225s |      0.11% |
# | Postprocessing                    |         6 |     0.196s |       9.9% |
# | Setup dof systems                 |         1 |    0.0526s |       2.6% |
# | Setup initial conditions          |         1 |      0.05s |       2.5% |
# | Setup matrices                    |         1 |    0.0799s |         4% |
# | Solve Stokes system               |         7 |     0.863s |        43% |
# | Solve temperature system          |         6 |     0.129s |       6.5% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 6:  t=120000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 126126
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.58366e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.17s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         8 |     0.173s |         8% |
# | Assemble Stokes system rhs        |         8 |     0.171s |       7.9% |
# | Assemble temperature system       |         7 |    0.0727s |       3.4% |
# | Build Stokes preconditioner       |         8 |    0.0049s |      0.23% |
# | Build temperature preconditioner  |         7 |    0.0037s |      0.17% |
# | Initialization                    |         1 |     0.111s |       5.1% |
# | Particles: Advect                 |        14 |   0.00482s |      0.22% |
# | Particles: Copy                   |         7 |   0.00172s |         0% |
# | Particles: Exchange ghosts        |         8 |   0.00586s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.12% |
# | Particles: Interpolate            |         7 |      0.02s |      0.92% |
# | Particles: Sort                   |        14 |   0.00515s |      0.24% |
# | Particles: Update properties      |         7 |   0.00263s |      0.12% |
# | Postprocessing                    |         7 |     0.219s |        10% |
# | Setup dof systems                 |         1 |    0.0526s |       2.4% |
# | Setup initial conditions          |         1 |      0.05s |       2.3% |
# | Setup matrices                    |         1 |    0.0799s |       3.7% |
# | Solve Stokes system               |         8 |     0.926s |        43% |
# | Solve temperature system          |         7 |      0.15s |       6.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 7:  t=140000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 4+0 iterations.
#       Newton system information: Norm of the rhs: 144692
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.81678e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.38s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         9 |     0.195s |       8.2% |
# | Assemble Stokes system rhs        |         9 |     0.192s |       8.1% |
# | Assemble temperature system       |         8 |    0.0822s |       3.4% |
# | Build Stokes preconditioner       |         9 |    0.0055s |      0.23% |
# | Build temperature preconditioner  |         8 |   0.00419s |      0.18% |
# | Initialization                    |         1 |     0.111s |       4.6% |
# | Particles: Advect                 |        16 |   0.00549s |      0.23% |
# | Particles: Copy                   |         8 |   0.00199s |         0% |
# | Particles: Exchange ghosts        |         9 |   0.00644s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |      0.11% |
# | Particles: Interpolate            |         8 |    0.0226s |      0.95% |
# | Particles: Sort                   |        16 |   0.00575s |      0.24% |
# | Particles: Update properties      |         8 |   0.00299s |      0.13% |
# | Postprocessing                    |         8 |     0.243s |        10% |
# | Setup dof systems                 |         1 |    0.0526s |       2.2% |
# | Setup initial conditions          |         1 |      0.05s |       2.1% |
# | Setup matrices                    |         1 |    0.0799s |       3.4% |
# | Solve Stokes system               |         9 |      1.02s |        43% |
# | Solve temperature system          |         8 |     0.171s |       7.2% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 8:  t=160000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 140748
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.76725e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.58s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        10 |     0.216s |       8.4% |
# | Assemble Stokes system rhs        |        10 |     0.214s |       8.3% |
# | Assemble temperature system       |         9 |    0.0915s |       3.5% |
# | Build Stokes preconditioner       |        10 |   0.00611s |      0.24% |
# | Build temperature preconditioner  |         9 |   0.00468s |      0.18% |
# | Initialization                    |         1 |     0.111s |       4.3% |
# | Particles: Advect                 |        18 |   0.00616s |      0.24% |
# | Particles: Copy                   |         9 |   0.00226s |         0% |
# | Particles: Exchange ghosts        |        10 |   0.00702s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |       0.1% |
# | Particles: Interpolate            |         9 |    0.0252s |      0.98% |
# | Particles: Sort                   |        18 |    0.0064s |      0.25% |
# | Particles: Update properties      |         9 |   0.00336s |      0.13% |
# | Postprocessing                    |         9 |     0.267s |        10% |
# | Setup dof systems                 |         1 |    0.0526s |         2% |
# | Setup initial conditions          |         1 |      0.05s |       1.9% |
# | Setup matrices                    |         1 |    0.0799s |       3.1% |
# | Solve Stokes system               |        10 |       1.1s |        43% |
# | Solve temperature system          |         9 |     0.191s |       7.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 9:  t=180000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 201254
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.52697e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.79s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        11 |     0.238s |       8.5% |
# | Assemble Stokes system rhs        |        11 |     0.235s |       8.4% |
# | Assemble temperature system       |        10 |     0.101s |       3.6% |
# | Build Stokes preconditioner       |        11 |   0.00671s |      0.24% |
# | Build temperature preconditioner  |        10 |   0.00515s |      0.18% |
# | Initialization                    |         1 |     0.111s |         4% |
# | Particles: Advect                 |        20 |   0.00683s |      0.24% |
# | Particles: Copy                   |        10 |   0.00245s |         0% |
# | Particles: Exchange ghosts        |        11 |    0.0076s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |        10 |    0.0278s |         1% |
# | Particles: Sort                   |        20 |   0.00698s |      0.25% |
# | Particles: Update properties      |        10 |   0.00375s |      0.13% |
# | Postprocessing                    |        10 |      0.29s |        10% |
# | Setup dof systems                 |         1 |    0.0526s |       1.9% |
# | Setup initial conditions          |         1 |      0.05s |       1.8% |
# | Setup matrices                    |         1 |    0.0799s |       2.9% |
# | Solve Stokes system               |        11 |      1.19s |        43% |
# | Solve temperature system          |        10 |     0.212s |       7.6% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 10:  t=200000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 4+0 iterations.
#       Newton system information: Norm of the rhs: 199268
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.50203e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box/solution/solution-00002
#      Writing particle output:             output_uplift_box/particles/particles-00002
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.03s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        12 |     0.259s |       8.6% |
# | Assemble Stokes system rhs        |        12 |     0.257s |       8.5% |
# | Assemble temperature system       |        11 |      0.11s |       3.6% |
# | Build Stokes preconditioner       |        12 |   0.00732s |      0.24% |
# | Build temperature preconditioner  |        11 |   0.00565s |      0.19% |
# | Initialization                    |         1 |     0.111s |       3.7% |
# | Particles: Advect                 |        22 |    0.0075s |      0.25% |
# | Particles: Copy                   |        11 |   0.00272s |         0% |
# | Particles: Exchange ghosts        |        12 |   0.00818s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |        11 |    0.0304s |         1% |
# | Particles: Sort                   |        22 |   0.00754s |      0.25% |
# | Particles: Update properties      |        11 |   0.00412s |      0.14% |
# | Postprocessing                    |        11 |     0.339s |        11% |
# | Setup dof systems                 |         1 |    0.0526s |       1.7% |
# | Setup initial conditions          |         1 |      0.05s |       1.6% |
# | Setup matrices                    |         1 |    0.0799s |       2.6% |
# | Solve Stokes system               |        12 |      1.29s |        43% |
# | Solve temperature system          |        11 |     0.233s |       7.7% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 11:  t=220000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 174993
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.19723e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.24s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        13 |     0.283s |       8.7% |
# | Assemble Stokes system rhs        |        13 |      0.28s |       8.6% |
# | Assemble temperature system       |        12 |     0.122s |       3.8% |
# | Build Stokes preconditioner       |        13 |   0.00821s |      0.25% |
# | Build temperature preconditioner  |        12 |   0.00629s |      0.19% |
# | Initialization                    |         1 |     0.111s |       3.4% |
# | Particles: Advect                 |        24 |   0.00859s |      0.27% |
# | Particles: Copy                   |        12 |   0.00302s |         0% |
# | Particles: Exchange ghosts        |        13 |   0.00881s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |        12 |    0.0332s |         1% |
# | Particles: Sort                   |        24 |   0.00822s |      0.25% |
# | Particles: Update properties      |        12 |    0.0047s |      0.15% |
# | Postprocessing                    |        12 |     0.363s |        11% |
# | Setup dof systems                 |         1 |    0.0526s |       1.6% |
# | Setup initial conditions          |         1 |      0.05s |       1.5% |
# | Setup matrices                    |         1 |    0.0799s |       2.5% |
# | Solve Stokes system               |        13 |      1.37s |        42% |
# | Solve temperature system          |        12 |     0.254s |       7.8% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 12:  t=240000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 189916
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.38462e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.45s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        14 |     0.304s |       8.8% |
# | Assemble Stokes system rhs        |        14 |     0.301s |       8.7% |
# | Assemble temperature system       |        13 |     0.131s |       3.8% |
# | Build Stokes preconditioner       |        14 |   0.00882s |      0.26% |
# | Build temperature preconditioner  |        13 |   0.00676s |       0.2% |
# | Initialization                    |         1 |     0.111s |       3.2% |
# | Particles: Advect                 |        26 |   0.00929s |      0.27% |
# | Particles: Copy                   |        13 |   0.00327s |         0% |
# | Particles: Exchange ghosts        |        14 |   0.00938s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |        13 |    0.0357s |         1% |
# | Particles: Sort                   |        26 |   0.00878s |      0.25% |
# | Particles: Update properties      |        13 |   0.00507s |      0.15% |
# | Postprocessing                    |        13 |     0.386s |        11% |
# | Setup dof systems                 |         1 |    0.0526s |       1.5% |
# | Setup initial conditions          |         1 |      0.05s |       1.5% |
# | Setup matrices                    |         1 |    0.0799s |       2.3% |
# | Solve Stokes system               |        14 |      1.46s |        42% |
# | Solve temperature system          |        13 |     0.275s |         8% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 13:  t=260000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 198260
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.48938e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.64s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        15 |     0.326s |       8.9% |
# | Assemble Stokes system rhs        |        15 |     0.323s |       8.9% |
# | Assemble temperature system       |        14 |     0.141s |       3.9% |
# | Build Stokes preconditioner       |        15 |   0.00943s |      0.26% |
# | Build temperature preconditioner  |        14 |   0.00724s |       0.2% |
# | Initialization                    |         1 |     0.111s |         3% |
# | Particles: Advect                 |        28 |   0.00996s |      0.27% |
# | Particles: Copy                   |        14 |   0.00353s |         0% |
# | Particles: Exchange ghosts        |        15 |   0.00996s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |        14 |    0.0384s |       1.1% |
# | Particles: Sort                   |        28 |   0.00935s |      0.26% |
# | Particles: Update properties      |        14 |   0.00543s |      0.15% |
# | Postprocessing                    |        14 |      0.41s |        11% |
# | Setup dof systems                 |         1 |    0.0526s |       1.4% |
# | Setup initial conditions          |         1 |      0.05s |       1.4% |
# | Setup matrices                    |         1 |    0.0799s |       2.2% |
# | Solve Stokes system               |        15 |      1.54s |        42% |
# | Solve temperature system          |        14 |     0.295s |       8.1% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 14:  t=280000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 2+0 iterations.
#       Newton system information: Norm of the rhs: 160561
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.01603e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.84s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        16 |     0.348s |         9% |
# | Assemble Stokes system rhs        |        16 |     0.344s |       8.9% |
# | Assemble temperature system       |        15 |      0.15s |       3.9% |
# | Build Stokes preconditioner       |        16 |      0.01s |      0.26% |
# | Build temperature preconditioner  |        15 |   0.00774s |       0.2% |
# | Initialization                    |         1 |     0.111s |       2.9% |
# | Particles: Advect                 |        30 |    0.0106s |      0.28% |
# | Particles: Copy                   |        15 |   0.00379s |         0% |
# | Particles: Exchange ghosts        |        16 |    0.0105s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |        15 |     0.041s |       1.1% |
# | Particles: Sort                   |        30 |   0.00991s |      0.26% |
# | Particles: Update properties      |        15 |   0.00579s |      0.15% |
# | Postprocessing                    |        15 |     0.433s |        11% |
# | Setup dof systems                 |         1 |    0.0526s |       1.4% |
# | Setup initial conditions          |         1 |      0.05s |       1.3% |
# | Setup matrices                    |         1 |    0.0799s |       2.1% |
# | Solve Stokes system               |        16 |      1.62s |        42% |
# | Solve temperature system          |        15 |     0.316s |       8.2% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 15:  t=300000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 4+0 iterations.
#       Newton system information: Norm of the rhs: 207408
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.60424e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box/solution/solution-00003
#      Writing particle output:             output_uplift_box/particles/particles-00003
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      4.09s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        17 |     0.369s |         9% |
# | Assemble Stokes system rhs        |        17 |     0.366s |       8.9% |
# | Assemble temperature system       |        16 |      0.16s |       3.9% |
# | Build Stokes preconditioner       |        17 |    0.0106s |      0.26% |
# | Build temperature preconditioner  |        16 |   0.00822s |       0.2% |
# | Initialization                    |         1 |     0.111s |       2.7% |
# | Particles: Advect                 |        32 |    0.0113s |      0.28% |
# | Particles: Copy                   |        16 |   0.00404s |         0% |
# | Particles: Exchange ghosts        |        17 |    0.0111s |      0.27% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |        16 |    0.0436s |       1.1% |
# | Particles: Sort                   |        32 |    0.0105s |      0.26% |
# | Particles: Update properties      |        16 |   0.00615s |      0.15% |
# | Postprocessing                    |        16 |     0.483s |        12% |
# | Setup dof systems                 |         1 |    0.0526s |       1.3% |
# | Setup initial conditions          |         1 |      0.05s |       1.2% |
# | Setup matrices                    |         1 |    0.0799s |         2% |
# | Solve Stokes system               |        17 |      1.72s |        42% |
# | Solve temperature system          |        16 |     0.336s |       8.2% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 16:  t=320000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 139867
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.75619e-07
#
#
#    Postprocessing:
# ...
# | Total wallclock time elapsed since start      |       218s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1002 |      22.5s |        10% |
# | Assemble Stokes system rhs        |      1000 |      22.5s |        10% |
# | Assemble temperature system       |       997 |      9.85s |       4.5% |
# | Build Stokes preconditioner       |      1000 |     0.631s |      0.29% |
# | Build temperature preconditioner  |       997 |     0.507s |      0.23% |
# | Initialization                    |         1 |     0.111s |         0% |
# | Particles: Advect                 |      1994 |     0.794s |      0.36% |
# | Particles: Copy                   |       997 |     0.293s |      0.13% |
# | Particles: Exchange ghosts        |       998 |     0.609s |      0.28% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |       997 |      2.69s |       1.2% |
# | Particles: Sort                   |      1994 |      0.66s |       0.3% |
# | Particles: Update properties      |       997 |     0.409s |      0.19% |
# | Postprocessing                    |       997 |      30.6s |        14% |
# | Setup dof systems                 |         1 |    0.0526s |         0% |
# | Setup initial conditions          |         1 |      0.05s |         0% |
# | Setup matrices                    |         1 |    0.0799s |         0% |
# | Solve Stokes system               |      1000 |      87.3s |        40% |
# | Solve temperature system          |       997 |      21.5s |       9.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 218s
# *** Timestep 997:  t=1.994e+07 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 194197
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.43837e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        96014
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       218s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1003 |      22.6s |        10% |
# | Assemble Stokes system rhs        |      1001 |      22.5s |        10% |
# | Assemble temperature system       |       998 |      9.86s |       4.5% |
# | Build Stokes preconditioner       |      1001 |     0.632s |      0.29% |
# | Build temperature preconditioner  |       998 |     0.507s |      0.23% |
# | Initialization                    |         1 |     0.111s |         0% |
# | Particles: Advect                 |      1996 |     0.794s |      0.36% |
# | Particles: Copy                   |       998 |     0.294s |      0.13% |
# | Particles: Exchange ghosts        |       999 |     0.609s |      0.28% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |       998 |       2.7s |       1.2% |
# | Particles: Sort                   |      1996 |     0.661s |       0.3% |
# | Particles: Update properties      |       998 |      0.41s |      0.19% |
# | Postprocessing                    |       998 |      30.6s |        14% |
# | Setup dof systems                 |         1 |    0.0526s |         0% |
# | Setup initial conditions          |         1 |      0.05s |         0% |
# | Setup matrices                    |         1 |    0.0799s |         0% |
# | Solve Stokes system               |      1001 |      87.3s |        40% |
# | Solve temperature system          |       998 |      21.5s |       9.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 218s
# *** Timestep 998:  t=1.996e+07 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 135252
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.69825e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        96012
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       218s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1004 |      22.6s |        10% |
# | Assemble Stokes system rhs        |      1002 |      22.6s |        10% |
# | Assemble temperature system       |       999 |      9.87s |       4.5% |
# | Build Stokes preconditioner       |      1002 |     0.633s |      0.29% |
# | Build temperature preconditioner  |       999 |     0.507s |      0.23% |
# | Initialization                    |         1 |     0.111s |         0% |
# | Particles: Advect                 |      1998 |     0.795s |      0.36% |
# | Particles: Copy                   |       999 |     0.294s |      0.13% |
# | Particles: Exchange ghosts        |      1000 |      0.61s |      0.28% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |       999 |       2.7s |       1.2% |
# | Particles: Sort                   |      1998 |     0.662s |       0.3% |
# | Particles: Update properties      |       999 |      0.41s |      0.19% |
# | Postprocessing                    |       999 |      30.6s |        14% |
# | Setup dof systems                 |         1 |    0.0526s |         0% |
# | Setup initial conditions          |         1 |      0.05s |         0% |
# | Setup matrices                    |         1 |    0.0799s |         0% |
# | Solve Stokes system               |      1002 |      87.4s |        40% |
# | Solve temperature system          |       999 |      21.6s |       9.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 218s
# *** Timestep 999:  t=1.998e+07 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 87660.8
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.10069e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        96012
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       218s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1005 |      22.6s |        10% |
# | Assemble Stokes system rhs        |      1003 |      22.6s |        10% |
# | Assemble temperature system       |      1000 |      9.88s |       4.5% |
# | Build Stokes preconditioner       |      1003 |     0.633s |      0.29% |
# | Build temperature preconditioner  |      1000 |     0.508s |      0.23% |
# | Initialization                    |         1 |     0.111s |         0% |
# | Particles: Advect                 |      2000 |     0.796s |      0.36% |
# | Particles: Copy                   |      1000 |     0.294s |      0.13% |
# | Particles: Exchange ghosts        |      1001 |     0.611s |      0.28% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |      1000 |       2.7s |       1.2% |
# | Particles: Sort                   |      2000 |     0.662s |       0.3% |
# | Particles: Update properties      |      1000 |     0.411s |      0.19% |
# | Postprocessing                    |      1000 |      30.7s |        14% |
# | Setup dof systems                 |         1 |    0.0526s |         0% |
# | Setup initial conditions          |         1 |      0.05s |         0% |
# | Setup matrices                    |         1 |    0.0799s |         0% |
# | Solve Stokes system               |      1003 |      87.5s |        40% |
# | Solve temperature system          |      1000 |      21.6s |       9.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 218s
# *** Timestep 1000:  t=2e+07 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 2+0 iterations.
#       Newton system information: Norm of the rhs: 143370
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.80019e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box/solution/solution-00200
#      Writing particle output:             output_uplift_box/particles/particles-00200
#      Particle count per cell min/avg/max: 25, 48, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       219s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1006 |      22.6s |        10% |
# | Assemble Stokes system rhs        |      1004 |      22.6s |        10% |
# | Assemble temperature system       |      1001 |      9.89s |       4.5% |
# | Build Stokes preconditioner       |      1004 |     0.634s |      0.29% |
# | Build temperature preconditioner  |      1001 |     0.508s |      0.23% |
# | Initialization                    |         1 |     0.111s |         0% |
# | Particles: Advect                 |      2002 |     0.797s |      0.36% |
# | Particles: Copy                   |      1001 |     0.295s |      0.13% |
# | Particles: Exchange ghosts        |      1002 |     0.611s |      0.28% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |      1001 |      2.71s |       1.2% |
# | Particles: Sort                   |      2002 |     0.663s |       0.3% |
# | Particles: Update properties      |      1001 |     0.411s |      0.19% |
# | Postprocessing                    |      1001 |      30.7s |        14% |
# | Setup dof systems                 |         1 |    0.0526s |         0% |
# | Setup initial conditions          |         1 |      0.05s |         0% |
# | Setup matrices                    |         1 |    0.0799s |         0% |
# | Solve Stokes system               |      1004 |      87.6s |        40% |
# | Solve temperature system          |      1001 |      21.6s |       9.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 219s
# Termination requested by criterion: end time
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       219s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1006 |      22.6s |        10% |
# | Assemble Stokes system rhs        |      1004 |      22.6s |        10% |
# | Assemble temperature system       |      1001 |      9.89s |       4.5% |
# | Build Stokes preconditioner       |      1004 |     0.634s |      0.29% |
# | Build temperature preconditioner  |      1001 |     0.508s |      0.23% |
# | Initialization                    |         1 |     0.111s |         0% |
# | Particles: Advect                 |      2002 |     0.797s |      0.36% |
# | Particles: Copy                   |      1001 |     0.295s |      0.13% |
# | Particles: Exchange ghosts        |      1002 |     0.611s |      0.28% |
# | Particles: Generate               |         1 |  0.000638s |         0% |
# | Particles: Initialization         |         1 |  5.76e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00268s |         0% |
# | Particles: Interpolate            |      1001 |      2.71s |       1.2% |
# | Particles: Sort                   |      2002 |     0.663s |       0.3% |
# | Particles: Update properties      |      1001 |     0.411s |      0.19% |
# | Postprocessing                    |      1001 |      30.7s |        14% |
# | Setup dof systems                 |         1 |    0.0526s |         0% |
# | Setup initial conditions          |         1 |      0.05s |         0% |
# | Setup matrices                    |         1 |    0.0799s |         0% |
# | Solve Stokes system               |      1004 |      87.6s |        40% |
# | Solve temperature system          |      1001 |      21.6s |       9.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 219s
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&NewtonSolver=1&cbfheatflux=1&mf=1&particles=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------
