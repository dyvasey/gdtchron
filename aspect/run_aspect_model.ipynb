# %% [markdown]
# # Run ASPECT model
# Running this notebook requires that ASPECT is installed and that optimized mode can be accessed with `aspect-release`. If you are using ASPECT in the accompanying Docker container, this is already enabled.
#
# The ASPECT model defined in the accompanying `uplift_box.prm` file and run here simulates uplift and erosion in a simplified manner to demonstrate the usage of GDTchron. In the model, a 100x20 km box is given a linear geothermal gradient of 30°C/km. No material moves for 10 Myr, allowing He and fission tracks to accumulate in the upper portion of the model. Then, uplift is simulated for 5 Myr at a rate of 1 mm/yr, or 5 km of total uplift. Uplifted material moves out of the top surface of the model, simulating perfectly efficient erosion, leaving younger ages near the top of the model. Then, uplift is stopped again for another 5 Myr allowing He and fission tracks to accumulate again.
#
# This first cell just finds the number of available processors on the device used and sets half that amount to be used by ASPECT. Note that commands starting with `!` are shell rather than Python commands

# %%
# Show number of available processors on local system and divide by 2
import os

os.environ['NP'] = str(int(os.cpu_count() / 2))

# !echo $NP
# Out:
# 10

# %% [markdown]
# The cell below runs ASPECT using the number of processors specified above on the included PRM file defining the ASPECT model

# %%
# Run ASPECT on uplift_box model with half the system processors
# !mpirun -np $NP aspect-release uplift_box.prm
# Out:
# -----------------------------------------------------------------------------
# --                             This is ASPECT                              --
# -- The Advanced Solver for Planetary Evolution, Convection, and Tectonics. --
# -----------------------------------------------------------------------------
# --     . version 3.1.0-pre (main, f56842eca)
# --     . using deal.II 9.5.1
# --     .       with 32 bit indices
# --     .       with vectorization level 0 (disabled, 1 doubles, 64 bits)
# --     . using Trilinos 13.2.0
# --     . using p4est 2.3.6
# --     . using Geodynamic World Builder 1.0.0
# --     . running in OPTIMIZED mode
# --     . running with 10 MPI processes
# -----------------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------------
# The output directory <output_uplift_box_fixed/> provided in the input file appears not to exist.
# ASPECT will create it for you.
# -----------------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&NewtonSolver=1&cbfheatflux=1&mf=1&particles=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------
# Number of active cells: 2,000 (on 3 levels)
# Number of degrees of freedom: 35,085 (16,482+2,121+8,241+8,241)
#
# *** Timestep 0:  t=0 years, dt=0 years
#    Solving temperature system... 0 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 1.70399e+12, v = 1.70399e+12, p = 0
#
#    Solving Stokes system (GMG)... 28+0 iterations.
#       Newton system information: Norm of the rhs: 1.70399e+12
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1
#
#    Solving Stokes system (GMG)... 27+0 iterations.
#       Newton system information: Norm of the rhs: 0.0465016, Derivative scaling factor: 0
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 2: 2.72899e-14
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box_fixed/solution/solution-00000
#      Writing particle output:             output_uplift_box_fixed/particles/particles-00000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       1.6s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         2 |     0.073s |       4.6% |
# | Assemble Stokes system rhs        |         2 |    0.0585s |       3.7% |
# | Assemble temperature system       |         1 |    0.0322s |         2% |
# | Build Stokes preconditioner       |         2 |   0.00619s |      0.39% |
# | Build temperature preconditioner  |         1 |   0.00578s |      0.36% |
# | Initialization                    |         1 |      0.18s |        11% |
# | Particles: Advect                 |         2 |   0.00474s |       0.3% |
# | Particles: Copy                   |         1 |   0.00165s |       0.1% |
# | Particles: Exchange ghosts        |         2 |   0.00505s |      0.32% |
# | Particles: Generate               |         1 |   0.00368s |      0.23% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |       0.5% |
# | Particles: Interpolate            |         1 |   0.00487s |       0.3% |
# | Particles: Sort                   |         2 |   0.00597s |      0.37% |
# | Particles: Update properties      |         1 |   0.00224s |      0.14% |
# | Postprocessing                    |         1 |    0.0733s |       4.6% |
# | Setup dof systems                 |         1 |     0.104s |       6.5% |
# | Setup initial conditions          |         1 |     0.068s |       4.2% |
# | Setup matrices                    |         1 |    0.0768s |       4.8% |
# | Solve Stokes system               |         2 |     0.829s |        52% |
# | Solve temperature system          |         1 |    0.0153s |      0.96% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 1:  t=20000 years, dt=20000 years
#    Solving temperature system... 18 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 1.27196e+12, v = 1.27196e+12, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 23076.6
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.81426e-08
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      1.86s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         3 |     0.114s |       6.2% |
# | Assemble Stokes system rhs        |         3 |    0.0901s |       4.8% |
# | Assemble temperature system       |         2 |    0.0601s |       3.2% |
# | Build Stokes preconditioner       |         3 |   0.00898s |      0.48% |
# | Build temperature preconditioner  |         2 |   0.00796s |      0.43% |
# | Initialization                    |         1 |      0.18s |       9.7% |
# | Particles: Advect                 |         4 |   0.00878s |      0.47% |
# | Particles: Copy                   |         2 |   0.00246s |      0.13% |
# | Particles: Exchange ghosts        |         3 |    0.0061s |      0.33% |
# | Particles: Generate               |         1 |   0.00368s |       0.2% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.43% |
# | Particles: Interpolate            |         2 |   0.00805s |      0.43% |
# | Particles: Sort                   |         4 |   0.00808s |      0.43% |
# | Particles: Update properties      |         2 |   0.00447s |      0.24% |
# | Postprocessing                    |         2 |     0.101s |       5.5% |
# | Setup dof systems                 |         1 |     0.104s |       5.6% |
# | Setup initial conditions          |         1 |     0.068s |       3.7% |
# | Setup matrices                    |         1 |    0.0768s |       4.1% |
# | Solve Stokes system               |         3 |     0.896s |        48% |
# | Solve temperature system          |         2 |    0.0451s |       2.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 2:  t=40000 years, dt=20000 years
#    Solving temperature system... 13 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 45313.9
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 5.68967e-08
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.09s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         4 |     0.142s |       6.8% |
# | Assemble Stokes system rhs        |         4 |     0.118s |       5.7% |
# | Assemble temperature system       |         3 |    0.0863s |       4.1% |
# | Build Stokes preconditioner       |         4 |    0.0117s |      0.56% |
# | Build temperature preconditioner  |         3 |   0.00997s |      0.48% |
# | Initialization                    |         1 |      0.18s |       8.6% |
# | Particles: Advect                 |         6 |    0.0128s |      0.61% |
# | Particles: Copy                   |         3 |   0.00327s |      0.16% |
# | Particles: Exchange ghosts        |         4 |   0.00713s |      0.34% |
# | Particles: Generate               |         1 |   0.00368s |      0.18% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.38% |
# | Particles: Interpolate            |         3 |    0.0111s |      0.53% |
# | Particles: Sort                   |         6 |   0.00996s |      0.48% |
# | Particles: Update properties      |         3 |   0.00656s |      0.31% |
# | Postprocessing                    |         3 |     0.129s |       6.2% |
# | Setup dof systems                 |         1 |     0.104s |         5% |
# | Setup initial conditions          |         1 |     0.068s |       3.3% |
# | Setup matrices                    |         1 |    0.0768s |       3.7% |
# | Solve Stokes system               |         4 |     0.962s |        46% |
# | Solve temperature system          |         3 |    0.0634s |         3% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 3:  t=60000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 66649.4
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 8.36859e-08
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.33s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         5 |     0.172s |       7.4% |
# | Assemble Stokes system rhs        |         5 |     0.148s |       6.3% |
# | Assemble temperature system       |         4 |     0.115s |       4.9% |
# | Build Stokes preconditioner       |         5 |    0.0157s |      0.67% |
# | Build temperature preconditioner  |         4 |    0.0122s |      0.52% |
# | Initialization                    |         1 |      0.18s |       7.7% |
# | Particles: Advect                 |         8 |    0.0169s |      0.72% |
# | Particles: Copy                   |         4 |   0.00408s |      0.17% |
# | Particles: Exchange ghosts        |         5 |   0.00806s |      0.35% |
# | Particles: Generate               |         1 |   0.00368s |      0.16% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.34% |
# | Particles: Interpolate            |         4 |    0.0149s |      0.64% |
# | Particles: Sort                   |         8 |    0.0117s |       0.5% |
# | Particles: Update properties      |         4 |   0.00884s |      0.38% |
# | Postprocessing                    |         4 |     0.154s |       6.6% |
# | Setup dof systems                 |         1 |     0.104s |       4.4% |
# | Setup initial conditions          |         1 |     0.068s |       2.9% |
# | Setup matrices                    |         1 |    0.0768s |       3.3% |
# | Solve Stokes system               |         5 |      1.03s |        44% |
# | Solve temperature system          |         4 |    0.0855s |       3.7% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 2s
# *** Timestep 4:  t=80000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 87171
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.09453e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.58s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         6 |       0.2s |       7.7% |
# | Assemble Stokes system rhs        |         6 |     0.174s |       6.7% |
# | Assemble temperature system       |         5 |     0.142s |       5.5% |
# | Build Stokes preconditioner       |         6 |    0.0185s |      0.71% |
# | Build temperature preconditioner  |         5 |    0.0141s |      0.55% |
# | Initialization                    |         1 |      0.18s |         7% |
# | Particles: Advect                 |        10 |    0.0203s |      0.79% |
# | Particles: Copy                   |         5 |   0.00491s |      0.19% |
# | Particles: Exchange ghosts        |         6 |   0.00898s |      0.35% |
# | Particles: Generate               |         1 |   0.00368s |      0.14% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.31% |
# | Particles: Interpolate            |         5 |    0.0177s |      0.69% |
# | Particles: Sort                   |        10 |    0.0134s |      0.52% |
# | Particles: Update properties      |         5 |     0.011s |      0.42% |
# | Postprocessing                    |         5 |     0.184s |       7.1% |
# | Setup dof systems                 |         1 |     0.104s |         4% |
# | Setup initial conditions          |         1 |     0.068s |       2.6% |
# | Setup matrices                    |         1 |    0.0768s |         3% |
# | Solve Stokes system               |         6 |      1.12s |        43% |
# | Solve temperature system          |         5 |     0.104s |         4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 5:  t=100000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 106972
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.34315e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box_fixed/solution/solution-00001
#      Writing particle output:             output_uplift_box_fixed/particles/particles-00001
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      2.86s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         7 |     0.231s |       8.1% |
# | Assemble Stokes system rhs        |         7 |     0.201s |         7% |
# | Assemble temperature system       |         6 |     0.169s |       5.9% |
# | Build Stokes preconditioner       |         7 |     0.021s |      0.74% |
# | Build temperature preconditioner  |         6 |    0.0161s |      0.56% |
# | Initialization                    |         1 |      0.18s |       6.3% |
# | Particles: Advect                 |        12 |    0.0243s |      0.85% |
# | Particles: Copy                   |         6 |   0.00585s |       0.2% |
# | Particles: Exchange ghosts        |         7 |    0.0104s |      0.37% |
# | Particles: Generate               |         1 |   0.00368s |      0.13% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.28% |
# | Particles: Interpolate            |         6 |    0.0219s |      0.77% |
# | Particles: Sort                   |        12 |    0.0151s |      0.53% |
# | Particles: Update properties      |         6 |    0.0131s |      0.46% |
# | Postprocessing                    |         6 |     0.244s |       8.5% |
# | Setup dof systems                 |         1 |     0.104s |       3.6% |
# | Setup initial conditions          |         1 |     0.068s |       2.4% |
# | Setup matrices                    |         1 |    0.0768s |       2.7% |
# | Solve Stokes system               |         7 |      1.19s |        42% |
# | Solve temperature system          |         6 |     0.125s |       4.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 6:  t=120000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 126126
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.58366e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.08s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         8 |     0.257s |       8.3% |
# | Assemble Stokes system rhs        |         8 |     0.229s |       7.4% |
# | Assemble temperature system       |         7 |     0.192s |       6.2% |
# | Build Stokes preconditioner       |         8 |    0.0237s |      0.77% |
# | Build temperature preconditioner  |         7 |    0.0179s |      0.58% |
# | Initialization                    |         1 |      0.18s |       5.8% |
# | Particles: Advect                 |        14 |    0.0284s |      0.92% |
# | Particles: Copy                   |         7 |   0.00665s |      0.22% |
# | Particles: Exchange ghosts        |         8 |    0.0115s |      0.37% |
# | Particles: Generate               |         1 |   0.00368s |      0.12% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.26% |
# | Particles: Interpolate            |         7 |    0.0247s |       0.8% |
# | Particles: Sort                   |        14 |    0.0168s |      0.54% |
# | Particles: Update properties      |         7 |    0.0153s |       0.5% |
# | Postprocessing                    |         7 |     0.269s |       8.7% |
# | Setup dof systems                 |         1 |     0.104s |       3.4% |
# | Setup initial conditions          |         1 |     0.068s |       2.2% |
# | Setup matrices                    |         1 |    0.0768s |       2.5% |
# | Solve Stokes system               |         8 |      1.25s |        41% |
# | Solve temperature system          |         7 |     0.146s |       4.7% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 7:  t=140000 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 4+0 iterations.
#       Newton system information: Norm of the rhs: 144692
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.81678e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.37s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |         9 |     0.286s |       8.5% |
# | Assemble Stokes system rhs        |         9 |     0.259s |       7.7% |
# | Assemble temperature system       |         8 |     0.214s |       6.4% |
# | Build Stokes preconditioner       |         9 |    0.0264s |      0.78% |
# | Build temperature preconditioner  |         8 |    0.0199s |      0.59% |
# | Initialization                    |         1 |      0.18s |       5.3% |
# | Particles: Advect                 |        16 |    0.0323s |      0.96% |
# | Particles: Copy                   |         8 |   0.00743s |      0.22% |
# | Particles: Exchange ghosts        |         9 |    0.0125s |      0.37% |
# | Particles: Generate               |         1 |   0.00368s |      0.11% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.24% |
# | Particles: Interpolate            |         8 |    0.0288s |      0.85% |
# | Particles: Sort                   |        16 |    0.0186s |      0.55% |
# | Particles: Update properties      |         8 |    0.0177s |      0.53% |
# | Postprocessing                    |         8 |     0.294s |       8.7% |
# | Setup dof systems                 |         1 |     0.104s |       3.1% |
# | Setup initial conditions          |         1 |     0.068s |         2% |
# | Setup matrices                    |         1 |    0.0768s |       2.3% |
# | Solve Stokes system               |         9 |      1.38s |        41% |
# | Solve temperature system          |         8 |     0.164s |       4.9% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 3s
# *** Timestep 8:  t=160000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 140714
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.76683e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.63s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        10 |     0.315s |       8.7% |
# | Assemble Stokes system rhs        |        10 |     0.283s |       7.8% |
# | Assemble temperature system       |         9 |     0.236s |       6.5% |
# | Build Stokes preconditioner       |        10 |    0.0286s |      0.79% |
# | Build temperature preconditioner  |         9 |    0.0216s |       0.6% |
# | Initialization                    |         1 |      0.18s |         5% |
# | Particles: Advect                 |        18 |    0.0362s |         1% |
# | Particles: Copy                   |         9 |   0.00824s |      0.23% |
# | Particles: Exchange ghosts        |        10 |    0.0136s |      0.37% |
# | Particles: Generate               |         1 |   0.00368s |       0.1% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.22% |
# | Particles: Interpolate            |         9 |    0.0317s |      0.87% |
# | Particles: Sort                   |        18 |    0.0203s |      0.56% |
# | Particles: Update properties      |         9 |      0.02s |      0.55% |
# | Postprocessing                    |         9 |     0.336s |       9.3% |
# | Setup dof systems                 |         1 |     0.104s |       2.9% |
# | Setup initial conditions          |         1 |     0.068s |       1.9% |
# | Setup matrices                    |         1 |    0.0768s |       2.1% |
# | Solve Stokes system               |        10 |      1.47s |        41% |
# | Solve temperature system          |         9 |     0.181s |         5% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 9:  t=180000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 201042
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.52432e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      3.99s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        11 |      0.35s |       8.8% |
# | Assemble Stokes system rhs        |        11 |     0.331s |       8.3% |
# | Assemble temperature system       |        10 |     0.277s |       6.9% |
# | Build Stokes preconditioner       |        11 |    0.0312s |      0.78% |
# | Build temperature preconditioner  |        10 |    0.0238s |       0.6% |
# | Initialization                    |         1 |      0.18s |       4.5% |
# | Particles: Advect                 |        20 |    0.0399s |         1% |
# | Particles: Copy                   |        10 |   0.00921s |      0.23% |
# | Particles: Exchange ghosts        |        11 |    0.0146s |      0.37% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |       0.2% |
# | Particles: Interpolate            |        10 |    0.0352s |      0.88% |
# | Particles: Sort                   |        20 |    0.0224s |      0.56% |
# | Particles: Update properties      |        10 |    0.0221s |      0.55% |
# | Postprocessing                    |        10 |     0.365s |       9.1% |
# | Setup dof systems                 |         1 |     0.104s |       2.6% |
# | Setup initial conditions          |         1 |     0.068s |       1.7% |
# | Setup matrices                    |         1 |    0.0768s |       1.9% |
# | Solve Stokes system               |        11 |       1.6s |        40% |
# | Solve temperature system          |        10 |     0.201s |         5% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 10:  t=200000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 4+0 iterations.
#       Newton system information: Norm of the rhs: 199992
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.51112e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box_fixed/solution/solution-00002
#      Writing particle output:             output_uplift_box_fixed/particles/particles-00002
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      4.44s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        12 |     0.397s |       8.9% |
# | Assemble Stokes system rhs        |        12 |     0.367s |       8.3% |
# | Assemble temperature system       |        11 |     0.332s |       7.5% |
# | Build Stokes preconditioner       |        12 |    0.0392s |      0.88% |
# | Build temperature preconditioner  |        11 |    0.0262s |      0.59% |
# | Initialization                    |         1 |      0.18s |       4.1% |
# | Particles: Advect                 |        22 |    0.0445s |         1% |
# | Particles: Copy                   |        11 |    0.0104s |      0.23% |
# | Particles: Exchange ghosts        |        12 |    0.0158s |      0.36% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.18% |
# | Particles: Interpolate            |        11 |    0.0393s |      0.89% |
# | Particles: Sort                   |        22 |    0.0245s |      0.55% |
# | Particles: Update properties      |        11 |    0.0246s |      0.55% |
# | Postprocessing                    |        11 |     0.431s |       9.7% |
# | Setup dof systems                 |         1 |     0.104s |       2.3% |
# | Setup initial conditions          |         1 |     0.068s |       1.5% |
# | Setup matrices                    |         1 |    0.0768s |       1.7% |
# | Solve Stokes system               |        12 |      1.74s |        39% |
# | Solve temperature system          |        11 |     0.224s |         5% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 4s
# *** Timestep 11:  t=220000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 174779
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.19455e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      4.73s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        13 |     0.427s |         9% |
# | Assemble Stokes system rhs        |        13 |     0.396s |       8.4% |
# | Assemble temperature system       |        12 |     0.361s |       7.6% |
# | Build Stokes preconditioner       |        13 |    0.0421s |      0.89% |
# | Build temperature preconditioner  |        12 |    0.0281s |      0.59% |
# | Initialization                    |         1 |      0.18s |       3.8% |
# | Particles: Advect                 |        24 |    0.0487s |         1% |
# | Particles: Copy                   |        12 |    0.0112s |      0.24% |
# | Particles: Exchange ghosts        |        13 |    0.0171s |      0.36% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.17% |
# | Particles: Interpolate            |        12 |    0.0425s |       0.9% |
# | Particles: Sort                   |        24 |    0.0264s |      0.56% |
# | Particles: Update properties      |        12 |    0.0267s |      0.57% |
# | Postprocessing                    |        12 |     0.459s |       9.7% |
# | Setup dof systems                 |         1 |     0.104s |       2.2% |
# | Setup initial conditions          |         1 |     0.068s |       1.4% |
# | Setup matrices                    |         1 |    0.0768s |       1.6% |
# | Solve Stokes system               |        13 |      1.83s |        39% |
# | Solve temperature system          |        12 |     0.259s |       5.5% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 5s
# *** Timestep 12:  t=240000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 195143
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.45024e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      5.04s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        14 |     0.459s |       9.1% |
# | Assemble Stokes system rhs        |        14 |     0.428s |       8.5% |
# | Assemble temperature system       |        13 |     0.392s |       7.8% |
# | Build Stokes preconditioner       |        14 |    0.0448s |      0.89% |
# | Build temperature preconditioner  |        13 |    0.0302s |       0.6% |
# | Initialization                    |         1 |      0.18s |       3.6% |
# | Particles: Advect                 |        26 |     0.053s |       1.1% |
# | Particles: Copy                   |        13 |    0.0121s |      0.24% |
# | Particles: Exchange ghosts        |        14 |    0.0182s |      0.36% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.16% |
# | Particles: Interpolate            |        13 |     0.046s |      0.91% |
# | Particles: Sort                   |        26 |    0.0286s |      0.57% |
# | Particles: Update properties      |        13 |    0.0291s |      0.58% |
# | Postprocessing                    |        13 |     0.491s |       9.7% |
# | Setup dof systems                 |         1 |     0.104s |       2.1% |
# | Setup initial conditions          |         1 |     0.068s |       1.3% |
# | Setup matrices                    |         1 |    0.0768s |       1.5% |
# | Solve Stokes system               |        14 |      1.96s |        39% |
# | Solve temperature system          |        13 |     0.278s |       5.5% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 5s
# *** Timestep 13:  t=260000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 196817
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.47126e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      5.29s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        15 |     0.489s |       9.2% |
# | Assemble Stokes system rhs        |        15 |     0.457s |       8.6% |
# | Assemble temperature system       |        14 |     0.416s |       7.9% |
# | Build Stokes preconditioner       |        15 |    0.0475s |       0.9% |
# | Build temperature preconditioner  |        14 |    0.0323s |      0.61% |
# | Initialization                    |         1 |      0.18s |       3.4% |
# | Particles: Advect                 |        28 |    0.0568s |       1.1% |
# | Particles: Copy                   |        14 |    0.0131s |      0.25% |
# | Particles: Exchange ghosts        |        15 |    0.0193s |      0.36% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.15% |
# | Particles: Interpolate            |        14 |    0.0491s |      0.93% |
# | Particles: Sort                   |        28 |    0.0303s |      0.57% |
# | Particles: Update properties      |        14 |    0.0314s |      0.59% |
# | Postprocessing                    |        14 |     0.519s |       9.8% |
# | Setup dof systems                 |         1 |     0.104s |         2% |
# | Setup initial conditions          |         1 |     0.068s |       1.3% |
# | Setup matrices                    |         1 |    0.0768s |       1.5% |
# | Solve Stokes system               |        15 |      2.04s |        39% |
# | Solve temperature system          |        14 |     0.295s |       5.6% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 5s
# *** Timestep 14:  t=280000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 157087
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.9724e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        98000
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      5.56s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        16 |     0.514s |       9.2% |
# | Assemble Stokes system rhs        |        16 |     0.482s |       8.7% |
# | Assemble temperature system       |        15 |     0.443s |         8% |
# | Build Stokes preconditioner       |        16 |    0.0502s |       0.9% |
# | Build temperature preconditioner  |        15 |    0.0342s |      0.62% |
# | Initialization                    |         1 |      0.18s |       3.2% |
# | Particles: Advect                 |        30 |    0.0606s |       1.1% |
# | Particles: Copy                   |        15 |    0.0141s |      0.25% |
# | Particles: Exchange ghosts        |        16 |    0.0202s |      0.36% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |      0.14% |
# | Particles: Interpolate            |        15 |    0.0518s |      0.93% |
# | Particles: Sort                   |        30 |    0.0319s |      0.57% |
# | Particles: Update properties      |        15 |    0.0331s |      0.59% |
# | Postprocessing                    |        15 |      0.55s |       9.9% |
# | Setup dof systems                 |         1 |     0.104s |       1.9% |
# | Setup initial conditions          |         1 |     0.068s |       1.2% |
# | Setup matrices                    |         1 |    0.0768s |       1.4% |
# | Solve Stokes system               |        16 |      2.16s |        39% |
# | Solve temperature system          |        15 |     0.311s |       5.6% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 6s
# *** Timestep 15:  t=300000 years, dt=20000 years
#    Solving temperature system... 11 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96423e+11, v = 7.96423e+11, p = 0
#
#    Solving Stokes system (GMG)... 1+0 iterations.
#       Newton system information: Norm of the rhs: 196424
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.46632e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box_fixed/solution/solution-00003
#      Writing particle output:             output_uplift_box_fixed/particles/particles-00003
#      Particle count per cell min/avg/max: 49, 49, 49
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |      5.86s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |        17 |     0.542s |       9.2% |
# | Assemble Stokes system rhs        |        17 |     0.521s |       8.9% |
# ...
# | Build Stokes preconditioner       |      1000 |      4.02s |      0.71% |
# | Build temperature preconditioner  |       997 |      3.15s |      0.56% |
# | Initialization                    |         1 |      0.18s |         0% |
# | Particles: Advect                 |      1994 |      6.12s |       1.1% |
# | Particles: Copy                   |       997 |      1.34s |      0.24% |
# | Particles: Exchange ghosts        |       998 |      1.88s |      0.33% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |         0% |
# | Particles: Interpolate            |       997 |      7.37s |       1.3% |
# | Particles: Sort                   |      1994 |      3.09s |      0.55% |
# | Particles: Update properties      |       997 |      3.35s |      0.59% |
# | Postprocessing                    |       997 |      73.6s |        13% |
# | Setup dof systems                 |         1 |     0.104s |         0% |
# | Setup initial conditions          |         1 |     0.068s |         0% |
# | Setup matrices                    |         1 |    0.0768s |         0% |
# | Solve Stokes system               |      1000 |       200s |        35% |
# | Solve temperature system          |       997 |      41.5s |       7.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 564s
# *** Timestep 997:  t=1.994e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 163638
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.05467e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        95984
#      Particle count per cell min/avg/max: 25, 47, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       564s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1003 |      60.9s |        11% |
# | Assemble Stokes system rhs        |      1001 |      59.9s |        11% |
# | Assemble temperature system       |       998 |      48.7s |       8.6% |
# | Build Stokes preconditioner       |      1001 |      4.02s |      0.71% |
# | Build temperature preconditioner  |       998 |      3.15s |      0.56% |
# | Initialization                    |         1 |      0.18s |         0% |
# | Particles: Advect                 |      1996 |      6.12s |       1.1% |
# | Particles: Copy                   |       998 |      1.34s |      0.24% |
# | Particles: Exchange ghosts        |       999 |      1.88s |      0.33% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |         0% |
# | Particles: Interpolate            |       998 |      7.37s |       1.3% |
# | Particles: Sort                   |      1996 |      3.09s |      0.55% |
# | Particles: Update properties      |       998 |      3.36s |      0.59% |
# | Postprocessing                    |       998 |      73.6s |        13% |
# | Setup dof systems                 |         1 |     0.104s |         0% |
# | Setup initial conditions          |         1 |     0.068s |         0% |
# | Setup matrices                    |         1 |    0.0768s |         0% |
# | Solve Stokes system               |      1001 |       200s |        35% |
# | Solve temperature system          |       998 |      41.6s |       7.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 564s
# *** Timestep 998:  t=1.996e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 4+0 iterations.
#       Newton system information: Norm of the rhs: 173760
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.18177e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        95981
#      Particle count per cell min/avg/max: 25, 47, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       565s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1004 |        61s |        11% |
# | Assemble Stokes system rhs        |      1002 |      59.9s |        11% |
# | Assemble temperature system       |       999 |      48.8s |       8.6% |
# | Build Stokes preconditioner       |      1002 |      4.03s |      0.71% |
# | Build temperature preconditioner  |       999 |      3.16s |      0.56% |
# | Initialization                    |         1 |      0.18s |         0% |
# | Particles: Advect                 |      1998 |      6.13s |       1.1% |
# | Particles: Copy                   |       999 |      1.34s |      0.24% |
# | Particles: Exchange ghosts        |      1000 |      1.88s |      0.33% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |         0% |
# | Particles: Interpolate            |       999 |      7.38s |       1.3% |
# | Particles: Sort                   |      1998 |      3.09s |      0.55% |
# | Particles: Update properties      |       999 |      3.36s |      0.59% |
# | Postprocessing                    |       999 |      73.7s |        13% |
# | Setup dof systems                 |         1 |     0.104s |         0% |
# | Setup initial conditions          |         1 |     0.068s |         0% |
# | Setup matrices                    |         1 |    0.0768s |         0% |
# | Solve Stokes system               |      1002 |       200s |        35% |
# | Solve temperature system          |       999 |      41.6s |       7.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 564s
# *** Timestep 999:  t=1.998e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 0+0 iterations.
#       Newton system information: Norm of the rhs: 124203
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 1.55952e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Number of advected particles:        95981
#      Particle count per cell min/avg/max: 25, 47, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       565s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1005 |        61s |        11% |
# | Assemble Stokes system rhs        |      1003 |        60s |        11% |
# | Assemble temperature system       |      1000 |      48.8s |       8.6% |
# | Build Stokes preconditioner       |      1003 |      4.03s |      0.71% |
# | Build temperature preconditioner  |      1000 |      3.16s |      0.56% |
# | Initialization                    |         1 |      0.18s |         0% |
# | Particles: Advect                 |      2000 |      6.14s |       1.1% |
# | Particles: Copy                   |      1000 |      1.34s |      0.24% |
# | Particles: Exchange ghosts        |      1001 |      1.88s |      0.33% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |         0% |
# | Particles: Interpolate            |      1000 |      7.38s |       1.3% |
# | Particles: Sort                   |      2000 |      3.09s |      0.55% |
# | Particles: Update properties      |      1000 |      3.36s |       0.6% |
# | Postprocessing                    |      1000 |      73.7s |        13% |
# | Setup dof systems                 |         1 |     0.104s |         0% |
# | Setup initial conditions          |         1 |     0.068s |         0% |
# | Setup matrices                    |         1 |    0.0768s |         0% |
# | Solve Stokes system               |      1003 |       200s |        35% |
# | Solve temperature system          |      1000 |      41.6s |       7.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 565s
# *** Timestep 1000:  t=2e+07 years, dt=20000 years
#    Solving temperature system... 12 iterations.
#    Advecting particles...  done.
#    Initial Newton Stokes residual = 7.96419e+11, v = 7.96419e+11, p = 0
#
#    Solving Stokes system (GMG)... 3+0 iterations.
#       Newton system information: Norm of the rhs: 215262
#       Relative nonlinear residual (Stokes system) after nonlinear iteration 1: 2.70287e-07
#
#
#    Postprocessing:
#      Compositions min/max/mass:           1/1/2e+09
#      Pressure min/avg/max:                -9.114e+07 Pa, 2.608e+08 Pa, 1.54e+09 Pa
#      Temperature min/avg/max:             273 K, 573.2 K, 873 K
#      Topography min/max:                  0 m, 0 m
#      RMS, max velocity:                   5.44e-06 m/year, 1.28e-05 m/year
#      Writing graphical output:            output_uplift_box_fixed/solution/solution-00200
#      Writing particle output:             output_uplift_box_fixed/particles/particles-00200
#      Particle count per cell min/avg/max: 25, 47, 65
#
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       566s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1006 |      61.1s |        11% |
# | Assemble Stokes system rhs        |      1004 |      60.1s |        11% |
# | Assemble temperature system       |      1001 |      48.9s |       8.6% |
# | Build Stokes preconditioner       |      1004 |      4.04s |      0.71% |
# | Build temperature preconditioner  |      1001 |      3.16s |      0.56% |
# | Initialization                    |         1 |      0.18s |         0% |
# | Particles: Advect                 |      2002 |      6.14s |       1.1% |
# | Particles: Copy                   |      1001 |      1.35s |      0.24% |
# | Particles: Exchange ghosts        |      1002 |      1.88s |      0.33% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |         0% |
# | Particles: Interpolate            |      1001 |      7.39s |       1.3% |
# | Particles: Sort                   |      2002 |       3.1s |      0.55% |
# | Particles: Update properties      |      1001 |      3.37s |       0.6% |
# | Postprocessing                    |      1001 |      73.9s |        13% |
# | Setup dof systems                 |         1 |     0.104s |         0% |
# | Setup initial conditions          |         1 |     0.068s |         0% |
# | Setup matrices                    |         1 |    0.0768s |         0% |
# | Solve Stokes system               |      1004 |       200s |        35% |
# | Solve temperature system          |      1001 |      41.7s |       7.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 566s
# Termination requested by criterion: end time
#
#
# +-----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start      |       566s |            |
# |                                               |            |            |
# | Section                           | no. calls |  wall time | % of total |
# +-----------------------------------+-----------+------------+------------+
# | Assemble Stokes system Picard rhs |      1006 |      61.1s |        11% |
# | Assemble Stokes system rhs        |      1004 |      60.1s |        11% |
# | Assemble temperature system       |      1001 |      48.9s |       8.6% |
# | Build Stokes preconditioner       |      1004 |      4.04s |      0.71% |
# | Build temperature preconditioner  |      1001 |      3.16s |      0.56% |
# | Initialization                    |         1 |      0.18s |         0% |
# | Particles: Advect                 |      2002 |      6.14s |       1.1% |
# | Particles: Copy                   |      1001 |      1.35s |      0.24% |
# | Particles: Exchange ghosts        |      1002 |      1.88s |      0.33% |
# | Particles: Generate               |         1 |   0.00368s |         0% |
# | Particles: Initialization         |         1 |  8.91e-05s |         0% |
# | Particles: Initialize properties  |         1 |   0.00803s |         0% |
# | Particles: Interpolate            |      1001 |      7.39s |       1.3% |
# | Particles: Sort                   |      2002 |       3.1s |      0.55% |
# | Particles: Update properties      |      1001 |      3.37s |       0.6% |
# | Postprocessing                    |      1001 |      73.9s |        13% |
# | Setup dof systems                 |         1 |     0.104s |         0% |
# | Setup initial conditions          |         1 |     0.068s |         0% |
# | Setup matrices                    |         1 |    0.0768s |         0% |
# | Solve Stokes system               |      1004 |       200s |        35% |
# | Solve temperature system          |      1001 |      41.7s |       7.4% |
# +-----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 566s
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&NewtonSolver=1&cbfheatflux=1&mf=1&particles=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------
